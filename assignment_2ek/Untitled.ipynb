# %%
polyA = ["A"]*6

# %%
print(polyA)
# Out:
# ['A', 'A', 'A', 'A', 'A', 'A']

# %%
gene = ["A","C","G","T","A","C"]
start_codon = gene[2:5]
print(start_codon)
# Out:
# ['G', 'T', 'A']

# %%
my_list = gene

# %%
print(my_list)
# Out:
# ['A', 'C', 'G', 'T', 'A', 'C']

# %%
t = ('a','b','c','d','e')
t1= 'a'
t = tuple()

# %%
t[3:5]
# Out:
# ()

# %%
aa2dna=dict()
aa2dna={}
aa2dna
# Out:
# {}

# %%
aa2dna={
          'met':('ATG',),
          'phe':('ACG','GCT,'),
}

# %%
aa2dna
# Out:
# {'met': ('ATG',), 'phe': ('ACG', 'GCT,')}

# %%
aa2dna.keys()
# Out:
# dict_keys(['met', 'phe'])

# %%
aa2dna.values()
# Out:
# dict_values([('ATG',), ('ACG', 'GCT,')])

# %%
5==5
# Out:
# True

# %%
6<4
# Out:
# False

# %%
x=11
if x>6:
    print('you are a fool')
# Out:
# you are a fool

# %%
x=6
if x%2 == 0:
    print('even_number')
else:
    print('odd_number')
# Out:
# even_number

# %%
x=73
y=54
if x>y:
    print('x is more than y')
elif y>x:
    print('y less than x')
else:
    print('x and y is equal')
# Out:
# x is more than y

# %%
name=input("what is your name")
# Out:
# what is your nametooobyyyy

# %%
name
# Out:
# 'tooobyyyy'

# %%
number=input('what is your fav number')
number=int(number)
if number>50:
    print("great job")
elif 0<number<50:
    print("you ok")
else:
    print("shit")
# Out:
# what is your fav number73
# great job
